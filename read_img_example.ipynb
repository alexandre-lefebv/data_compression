# %%
import numpy as np
import matplotlib.pyplot as plt

# Format
width = 176
height = 144

path = "./videos/"
# Images
# fname = "akiyo.qcif"
# fname = "carphone.qcif"
fname = "coastguard.qcif"
# fname = "hall.qcif"
# fname = "news.qcif"

# %%
from video import Video

# %%
video = Video(path+fname)

if not video.EOF:
    compY, compU, compV = video.read_img()
    plt.figure(figsize=(20,10))
    plt.subplot(1,2,1)
    plt.imshow(compY)
    plt.subplot(2,4,3)
    plt.imshow(compU)
    plt.subplot(2,4,7)
    plt.imshow(compV)
    plt.show()

# skip some images
for k in range(30):
    video.read_img()

if not video.EOF:
    compY, compU, compV = video.read_img()
    plt.figure(figsize=(20,10))
    plt.subplot(1,2,1)
    plt.imshow(compY)
    plt.subplot(2,4,3)
    plt.imshow(compU)
    plt.subplot(2,4,7)
    plt.imshow(compV)
    plt.show()
